# %% [markdown]
# <a href="https://colab.research.google.com/github/NavyaSri-2001/Python_Files/blob/main/Pandas_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df1=pd.read_csv('/content/df1',index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2=pd.read_csv('/content/df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3=pd.read_csv('/content/df3')
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.area(alpha=0.3)
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)#for bar plot, index has to be categorical and it plots all cols on those indexes
# Out:
# <Axes: >

# %%
df1.plot.line(x='A',y='B', figsize=(12,3), lw=1)
# Out:
# <Axes: xlabel='A'>

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')#c stands for color
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=['A','B'])
df.head()
# Out:
#           A         B
# 0  1.183847  2.073345
# 1  1.543057  0.368603
# 2 -1.418153 -0.277877
# 3 -1.126252 -0.792631
# 4  0.065590 -0.390861

# %%
df.plot.hexbin(x='A',y='B', gridsize=25)
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
#density plot #same as above
df2.plot.density()
# Out:
# <Axes: ylabel='Density'>
