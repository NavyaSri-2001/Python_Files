# %% [markdown]
# <a href="https://colab.research.google.com/github/NavyaSri-2001/Python_Files/blob/main/Regression_plots%2C_style_and_color_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
# %matplotlib inline
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#linear model plot
sns.lmplot(data=tips,x='total_bill',y='tip',hue='sex',markers=['o','v'], scatter_kws={'s':100} )

# %%
sns.lmplot(data=tips,x='total_bill',y='tip',col='day',row='time',hue='sex',aspect=0.6)

# %%
#Style and Color
sns.set_style('ticks')
sns.countplot(x='sex',data=tips)
#sns.despine(left=True, bottom=True)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.set_context('poster',font_scale=2)
sns.countplot(x='sex', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.set_context('notebook')
sns.lmplot(x='total_bill', y='tip',data=tips,hue='sex',palette='coolwarm')
